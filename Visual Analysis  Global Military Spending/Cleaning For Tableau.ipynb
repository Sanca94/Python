# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Military Expenditure.csv')

# %%
df = df.drop(['Indicator Name'], axis=1)

# %%
df.shape
# Out:
# (264, 62)

# %%
df.head()
# Out:
#           Name Code     Type  1960  1961  1962  1963  1964  1965  1966  ...  \
# 0        Aruba  ABW  Country   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1  Afghanistan  AFG  Country   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2       Angola  AGO  Country   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 3      Albania  ALB  Country   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 4      Andorra  AND  Country   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#            2009          2010          2011          2012          2013  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1  2.518695e+08  2.981469e+08  3.258070e+08  2.385834e+08  2.171941e+08
# 2  3.311193e+09  3.500795e+09  3.639496e+09  4.144635e+09  6.090752e+09
# 3  1.827369e+08  1.858932e+08  1.970068e+08  1.832047e+08  1.800155e+08
# 4           NaN           NaN           NaN           NaN           NaN
#
#            2014          2015          2016          2017          2018
# 0           NaN           NaN           NaN           NaN           NaN
# 1  2.682271e+08  1.995186e+08  1.858783e+08  1.914071e+08  1.980863e+08
# 2  6.841864e+09  3.608299e+09  2.764055e+09  3.062873e+09  1.983614e+09
# 3  1.781204e+08  1.323507e+08  1.308532e+08  1.443827e+08  1.804887e+08
# 4           NaN           NaN           NaN           NaN           NaN
#
# [5 rows x 62 columns]

# %%
Countires = df[df['Type']=='Country'] # isolates the data points to countires
Countires = Countires.drop(['Code', 'Type'], axis=1) # drops code/type
Countires = Countires.set_index('Name')
Countires.index = Countires.index.rename('Year')
Countires = Countires.dropna(axis=0, how='all') # if a column is all null drop
Countires.head()
# Out:
#                       1960  1961         1962         1963         1964  \
# Year
# Afghanistan            NaN   NaN          NaN          NaN          NaN
# Angola                 NaN   NaN          NaN          NaN          NaN
# Albania                NaN   NaN          NaN          NaN          NaN
# United Arab Emirates   NaN   NaN          NaN          NaN          NaN
# Argentina              NaN   NaN  305162407.2  242219771.2  245740498.0
#
#                              1965         1966         1967         1968  \
# Year
# Afghanistan                   NaN          NaN          NaN          NaN
# Angola                        NaN          NaN          NaN          NaN
# Albania                       NaN          NaN          NaN          NaN
# United Arab Emirates          NaN          NaN          NaN          NaN
# Argentina             252407602.9  279225436.3  251930719.1  337142857.1
#
#                              1969  ...          2009          2010  \
# Year                               ...
# Afghanistan                   NaN  ...  2.518695e+08  2.981469e+08
# Angola                        NaN  ...  3.311193e+09  3.500795e+09
# Albania                       NaN  ...  1.827369e+08  1.858932e+08
# United Arab Emirates          NaN  ...  1.383635e+10  1.750470e+10
# Argentina             442857142.9  ...  2.981852e+09  3.475348e+09
#
#                               2011          2012          2013          2014  \
# Year
# Afghanistan           3.258070e+08  2.385834e+08  2.171941e+08  2.682271e+08
# Angola                3.639496e+09  4.144635e+09  6.090752e+09  6.841864e+09
# Albania               1.970068e+08  1.832047e+08  1.800155e+08  1.781204e+08
# United Arab Emirates  1.918176e+10  1.902410e+10  2.356106e+10  2.275507e+10
# Argentina             4.051930e+09  4.563218e+09  5.137974e+09  4.979443e+09
#
#                               2015          2016          2017          2018
# Year
# Afghanistan           1.995186e+08  1.858783e+08  1.914071e+08  1.980863e+08
# Angola                3.608299e+09  2.764055e+09  3.062873e+09  1.983614e+09
# Albania               1.323507e+08  1.308532e+08  1.443827e+08  1.804887e+08
# United Arab Emirates           NaN           NaN           NaN           NaN
# Argentina             5.482617e+09  4.509648e+09  5.459644e+09  4.144992e+09
#
# [5 rows x 59 columns]

# %%
Countires = Countires.T # the countries are now columns
Countires = Countires.fillna(Countires.mean())
Countires.head()

# %%
#Countires.to_csv("Military_Tab.csv")
